# %%
#To give last didit of a number
a = int(input("Enter a number : "))
b = a%10
print("Last digit :",b)
# Out:
# Enter a number : 209
# Last digit : 9

# %%
a=int(input("Length : "))
b=int(input("Breadth : "))
print("Area of rectangle is",a*b,"Perimeter is",2*a*b)
# Out:
# Length : 6
# Breadth : 4
# Area of rectangle is 24 Perimeter is 48

# %%
# To find whether a number is prime

def is_prime(n):
  if n <= 1:
    return False
  for i in range(2, int(n**0.5) + 1):
    if n % i == 0:
      return False
  return True
a = int(input("Number: "))
if is_prime(a):
  print("The number is prime")
else:
  print("The number is not prime")
# Out:
# Number: 19
# The number is prime

# %%
#Largest number
a=int(input())
b=int(input())
c=int(input())
if a>b and a>c :
  print("a is largest")
elif b>c and b>a :
  print("b is largest")
elif c>a and c>b :
  print("c is largest")
elif a==b and b==c :
  print("all 3 are equal")
# Out:
# 1
# 1
# 1
# all 3 are equal

# %%
#Python program to calculate electricity bill (accept no of unit from user) according to following criteria: Unit Price
#First 100 units  no charge
#Next 100 units Rs 5 per Unit
#After 200 Units Rs 10 per Unit
#(For Example if input unit is 350 then total bill amount is 2000)
a=int(input("Enter number of units :"))
if a<=100 :
  print("No charge")
elif a>100 and a<=200:
  print("Electricity bill",(a-100)*5)
elif a>200 :
  print("Electricity bill",(5*100)+(a-200)*10)
# Out:
# Enter number of units :350
# Electricity bill 2000

# %%
#Write a program to accept numbers from 1-7 and display name of day like- 1 for sunday, 2 for Monday and so on.
Days = {
  1: "Sunday",
  2: "Monday",
  3: "Tuesday",
  4: "Wednesday",
  5: "Thursday",
  6: "Friday",
  7: "Saturday"
}
a = int(input("Enter value : "))
print(Days[a])
# Out:
# Enter value : 5
# Thursday

# %%
#Write a python program to check given word is Palindrome or not
a=input("Enter word in lower case or upper case :")
if a==a[::-1]:
  print("Its a palindrome")
else:
  print("Not a palindrome")
# Out:
# Enter word in lower case or upper case :naman
# Its a palindrome

# %%
import pandas as pd
import numpy as np

# %%
hp=pd.read_csv('/content/House Price India.csv')
df = pd.DataFrame(hp)

# %%
df
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
df.drop(columns=['Lattitude','Longitude','id','Date'],inplace=True)

# %%
#For univariate analysis
df.describe()
# Out:
#        number of bedrooms  number of bathrooms   living area      lot area  \
# count        14620.000000         14620.000000  14620.000000  1.462000e+04
# mean             3.379343             2.129583   2098.262996  1.509328e+04
# std              0.938719             0.769934    928.275721  3.791962e+04
# min              1.000000             0.500000    370.000000  5.200000e+02
# 25%              3.000000             1.750000   1440.000000  5.010750e+03
# 50%              3.000000             2.250000   1930.000000  7.620000e+03
# 75%              4.000000             2.500000   2570.000000  1.080000e+04
# max             33.000000             8.000000  13540.000000  1.074218e+06
#
#        number of floors  waterfront present  number of views  \
# count      14620.000000        14620.000000     14620.000000
# mean           1.502360            0.007661         0.233105
# std            0.540239            0.087193         0.766259
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.boxplot(df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x798130e50df0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x798130e52770>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x798130e50880>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x798130e52da0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x798130e51960>,
# ...
#  'means': []}

# %%
#Bivariate analysis
df.columns
# Out:
# Index(['number of bedrooms', 'number of bathrooms', 'living area', 'lot area',
#        'number of floors', 'waterfront present', 'number of views',
#        'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'living_area_renov',
#        'lot_area_renov', 'Number of schools nearby',
#        'Distance from the airport', 'Price'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'df'
plt.figure(figsize=(8, 6))  # Set a reasonable figure size

# Assuming 'number of bedrooms' and 'living area' are column names in 'df'
plt.scatter(df'Distance from the airport'], df['Price'])

# Add labels and title for clarity
plt.xlabel('Number of Bedrooms')
plt.ylabel('Price')


# Optional: Customize plot appearance
plt.grid(True)  # Add a grid for better readability

plt.show()
